# %%
import pandas as pd

# %%
df = pd.read_excel("D:\Companies\Study\Projects\Retail Customer Analytics Platform\data\Online Retail.xlsx")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\akars\AppData\Local\Temp\ipykernel_24832\1101435094.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df = pd.read_excel("D:\Companies\Study\Projects\Retail Customer Analytics Platform\data\Online Retail.xlsx")
